# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # a)

# %%
x ,y = np.random.multivariate_normal([0, 0],[[1, 0],[0, 1]],100).T

plt.scatter(x,y)

# %% [markdown]
# # b)

# %%
x ,y = np.random.multivariate_normal([-1, 1],[[1, 0],[0, 1]],100).T

plt.scatter(x,y)

# %% [markdown]
# # C)

# %%
x ,y = np.random.multivariate_normal([0, 0],[[2, 0],[0, 2]],100).T

plt.scatter(x,y)

# %% [markdown]
# # d)

# %%
x ,y = np.random.multivariate_normal([0, 0],[[1, 0.5],[0.5, 1]],100).T

plt.scatter(x,y)

# %% [markdown]
# # e)

# %%
x ,y = np.random.multivariate_normal([0, 0],[[1, -0.5],[-0.5, 1]],100).T

plt.scatter(x,y)
